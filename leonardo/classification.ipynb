# %%
import pandas as pd
from sklearn.svm import LinearSVC

# %%
#Load Train Data
subset = 'train'

folder = "..\\data\\"
file =  subset + "\\" + subset + ".csv"

train_raw_df = pd.read_csv(folder + file,sep=",")
train_raw_df.head()

hogpath = folder + 'resized\\' + subset + '\\' + subset + "_hog.csv"
train_hog_df = pd.read_csv(hogpath,sep=",")
train_hog_df.head()
# Out:
#    observationid  mediaid  vote content  classid       family           genus  \
# 0          12510     1648   4.0  Flower     4369  Primulaceae         Primula
# 1          27147   111066   3.0  Flower    30162  Orchidaceae  Himantoglossum
# 2          35639    17104   3.0  Flower     6538  Orchidaceae      Anacamptis
# 3          18747    30734   3.0  Flower     6415  Orchidaceae          Orchis
# 4          26828    71634   4.0  Flower     5148   Salicaceae           Salix
#
#                                              species            author  \
# 0                                   Primula veris L.  liliane roubaudi
# 1               Himantoglossum hircinum (L.) Spreng.   julien barataud
# 2  Anacamptis morio (L.) R.M.Bateman, Pridgeon & ...      marie portas
# 3                     Orchis anthropophora (L.) All.        errol vela
# 4                                    Salix caprea L.    inge wullweber
#
#         date                 location  latitude  longitude     yearinclef  \
# 0   2014-4-1  La Chapelle en Guinchay       NaN        NaN  PlantCLEF2015
# 1  2006-6-14                 Plévenon       NaN        NaN  ImageCLEF2013
# 2  2012-3-19                   Hyères       NaN        NaN  ImageCLEF2013
# 3  2014-4-11       Sidi Aich, ALGERIE   36.6026    4.69448  PlantCLEF2015
# 4  2009-3-11                      NaN       NaN        NaN  PlantCLEF2014
#
#    observationid2014  imageid2014 learntag
# 0                NaN          NaN    Train
# 1            14913.0      48553.0    Train
# 2             6637.0      33907.0    Train
# 3                NaN          NaN    Train
# 4             2982.0      58691.0    Train

# %%
clf = LinearSVC(random_state=0, tol=1e-5)
X_train = train_hog_df
y_train = train_raw_df['classid']

clf.fit(X_train, y_train)
# Out:
# d:\onedrive\documentos\github\classificationplantes\env\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=0, tol=1e-05,
#           verbose=0)

# %%
#Load Test Data
subset = 'test'
file =  subset + "\\" + subset + ".csv"

test_raw_df = pd.read_csv(folder + file,sep=",")
test_raw_df.head()

hogpath = folder + 'resized\\' + subset + '\\' + subset + "_hog.csv"
test_hog_df = pd.read_csv(hogpath,sep=",")
test_hog_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.179221  0.081028  0.123121  0.648097  0.648097  0.325725  0.000000
# 1  0.396624  0.000000  0.076737  0.381549  0.415699  0.415699  0.415699
# 2  0.261167  0.069085  0.188815  0.244382  0.517343  0.517343  0.517343
# 3  0.365089  0.312301  0.365089  0.365089  0.365089  0.365089  0.365089
# 4  0.529819  0.529819  0.499417  0.029675  0.412902  0.062951  0.041967
#
#           7         8         9  ...      7190      7191      7192      7193  \
# 0  0.000000  0.462331  0.115004  ...  0.231105  0.377541  0.377024  0.154577
# 1  0.415699  0.494904  0.047025  ...  0.339789  0.211784  0.412920  0.412920
# 2  0.169456  0.426385  0.161061  ...  0.164232  0.033039  0.454854  0.361321
# 3  0.320509  0.359549  0.359549  ...  0.536307  0.000000  0.458736  0.401347
# 4  0.109886  0.390906  0.245094  ...  0.370937  0.315442  0.485862  0.485862
#
#        7194      7195      7196      7197      7198      7199
# 0  0.377024  0.377024  0.377024  0.377024  0.377024  0.351032
# 1  0.321425  0.205585  0.412920  0.412920  0.412920  0.043653
# 2  0.166596  0.454854  0.454854  0.017353  0.117572  0.454854
# 3  0.124761  0.300086  0.458736  0.189660  0.458736  0.256940
# 4  0.485862  0.097743  0.485862  0.000000  0.181371  0.115334
#
# [5 rows x 7200 columns]

# %%
X_test = test_hog_df
y_test = test_raw_df['classid']
